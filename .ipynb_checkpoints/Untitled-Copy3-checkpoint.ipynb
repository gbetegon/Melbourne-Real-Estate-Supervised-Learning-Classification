# %% [markdown]
# ## Building a Classifier and Regressor based on Melbourne's house data
#
# Add text

# %% [markdown]
# ## Modules

# %%
import re
import itertools
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mstats

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style("darkgrid")

# %% [markdown]
# ## Load Data

# %%
#Load into dataframe
path = '/Users/Stephanie/desktop/thinkful/capstone - supervised learning/'
file = 'Melbourne_housing_FULL.csv'

df = pd.read_csv(path + file)

# %% [markdown]
# ## First High-level exploration Exploration
#
# Let's start by taking a look at the dataframe we just created.

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN  Yarra City Council  -37.8014    144.9958
# 1           NaN        NaN  Yarra City Council  -37.7996    144.9984
# 2          79.0     1900.0  Yarra City Council  -37.8079    144.9934
# 3           NaN        NaN  Yarra City Council  -37.8114    145.0116
# 4         150.0     1900.0  Yarra City Council  -37.8093    144.9944
#
#               Regionname Propertycount
# 0  Northern Metropolitan        4019.0
# 1  Northern Metropolitan        4019.0
# 2  Northern Metropolitan        4019.0
# 3  Northern Metropolitan        4019.0
# 4  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 5.6+ MB

# %% [markdown]
# Our dataframe is made out of almost 35k rows of information and 22 different variables, which can be continous (e.g. 'Price'), discrete (e.g. 'Rooms') or categorical (e.g. 'Type').
#
# From the start we see that a lot of variables have some level of missing data. We'll deal with this in a bit.
#
# Also, the 'Date' variable seem to be stored as a string rather than a date. Let's change that

# %%
# date is stored in the european format
print(df.Date[25:30])

# convert to datetime
df['Date'] = pd.to_datetime(df['Date'])
print('Variable dtype converted to datetime')
# Out:
# 25    12/11/2016
# 26    12/11/2016
# 27    12/11/2016
# 28    13/08/2016
# 29    14/05/2016
# Name: Date, dtype: object
# Variable dtype converted to datetime

# %% [markdown]
# ## Split the data in train and test setsv

# %% [markdown]
# Before continuing our exploration we're going to split the dataset in two packages: a train set and a test set (20% holdout). The test set will simmulate how or model would deal in production with new data.
#
# Continue explanation

# %%
train, test = train_test_split(df, test_size=0.2, random_state=13)

train_len = len(train) # will use to split again in the future
data = pd.concat(objs=[train, test], axis=0)

# %% [markdown]
# ## Missing Data
#
# After splitting the data, let's get back to where we were. We know we have some missing data, but we need to find out is we really have a serious issue

# %%
cols_with_na = len(data.columns[data.isna().any() == True])
total_cols = len(data.columns)

print('%d columns out of %d have missing data'%(cols_with_na, total_cols))
# Out:
# 14 columns out of 21 have missing data

# %% [markdown]
# It's not looking good, but it might be just a few rows... why don't we build a little chart to get a better idea?

# %%
# plot percentage and number of missing values
na = data.isna().sum()
na = na[na > 0].sort_values(ascending=False)
pctage = round(na/len(df)*100,3)

plt.figure(figsize=(12, 4))
sns.barplot(x=pctage.index, y=pctage)
plt.xticks(rotation=90)
for x, y, label in list(zip(range(0,(len(pctage))), pctage, na)):
    plt.text(x, y, label, fontsize=12, horizontalalignment='center', verticalalignment='bottom')
plt.show()

# %% [markdown]
# For 5 of the 14 columns the amount of missing data is actually insignificant. It happens to be the case that is all concretated on the same 3 rows that we'll just drop out of the dataframe.

# %%
# all these missing values belong to the same three rows that we'll remove
# we wouldn't remove them from the original dataframe if it was a higher number
drop = data[data['Propertycount'].isna()].index
data.drop(drop, inplace=True)
print('Rows dropped:', len(data.iloc[drop]))
# Out:
# Rows dropped: 3

# %% [markdown]
#  However, we have a big issue for the rest of variables, particularly 'Building Area' and 'Year Built' which have more than a 50% of missing data. The rest of variables move around 20 to 25%.
#
#  Explain the rest and talk about MAR too. See if train and test are equally affected

# %% [markdown]
# We're going to create three dfs from our original as different approaches to missing values.
# - __df_all_na__: we won't drop any missing value.
# - __df_some_na__: we'll drop all na values for all columns except 'BuildingArea' and 'YearBuilt'
# - __df_no_na__: we'll drop all na values
#
# When preprocessing the data we will impute any existing na value on df_all_na, and df_some_na. Explain why not now

# %% [markdown]
# cols_with_na_to_drop = df.columns.drop(['BuildingArea', 'YearBuilt'])
# to_drop = df[df[cols_with_na_to_drop].isna().any(axis=1)].index
#
# df_all_na = df.copy()
# df_some_na = df_all_na.drop(to_drop)
# df_no_na = df_all_na.dropna()
# print('Rows on df_all_na: ', len(df_all_na))
# print('Rows on df_some_na:', len(df_some_na))
# print('Rows on df_no_na:  ', len(df_no_na))

# %% [markdown]
# ### Dealing with missing data
#
# We now have three distinct groups of variables: those with no missing data, those with a significant level of missing data, and those that miss most of the data. We're have different solutions that we can try and we'll test a few things.
#
# First we can drop information: bla bla bla
#
# Another solution is to impute the missing information. A common approach is to use the mean, median or model depending on the variable type. bla bla bla

# %%
skws = {"s": 8, "alpha": 0.2}
sns.lmplot(x='Longtitude', y='Lattitude',
           data=data, hue='Regionname', size=8, fit_reg=False, scatter_kws=skws
          )

# %%
# Create abbreviated acronyms for region
data['Region'] = data['Regionname'].apply(
                                    lambda x: ''.join(e[0] for e in re.split(' |-', x))
                                         )

# %%
# use train set, avoid data leakage
train = data[:train_len]

# Select columns that have NaN values (excluding longt. and latt.)
to_plot = train[train.columns[train.count() < len(train)].drop(['Longtitude', 'Lattitude'])]
to_plot['Region'] = train['Region']

# See if region differences are significant on variables with missing values
plt.figure(figsize=(12,8))
subplot_num = range(1,9)
for col, number in list(zip(to_plot.columns.drop('Region'), subplot_num)):
    plt.subplot(240 + number)
    sns.pointplot(x='Region', y=col, data=to_plot)

# %% [markdown]
# It looks like bla bla bla (mention outliers too)

# %% [markdown]
# ## Data distribution and dealing with outliers

# %%
to_plot = train.select_dtypes(include=['float64', 'int'])
to_plot.hist(figsize=(12, 12), grid=False)
plt.show()

# %% [markdown]
# Many of the variables histograms show outliers that are compressing the majority of data to one side of the x axis and so masking a lof of the detail the distribution. Outliers can be due to an error or just be rare cases, which is probably the case for most of the outliers in our dataset (after we all know of houses ridiculously big and expensive.
#
# Mention possible erros on test set
#
# One case however, stands as an error, as buildings in Melbourne can't date older than the early 1800s but we seem to have something much older. Let's take a look at that

# %%
outliers = train['YearBuilt'] < 1850
train.loc[outliers , 'YearBuilt']
# Out:
# 3533     1830.0
# 16424    1196.0
# Name: YearBuilt, dtype: float64

# %% [markdown]
# 1196 has to be an error, and we'll change the value for 1916

# %%
data.loc[16424,'YearBuilt'] = 1916

# %% [markdown]
# Now let's see how our data looks if we limit the maximum values within a 99% confidence interval (pretty high, we're only affecting the most extreme values)

# %% [markdown]
# SQUIZE MORE PLOTS In??

# %%
# Winsorize data
to_plot_win = to_plot

for col in to_plot_win:
    not_null = to_plot[col].notnull()
    to_plot_win.loc[not_null, col] = mstats.winsorize(to_plot.loc[not_null, col], limits=0.01)

# plot winsorized data
to_plot_win = to_plot_win.select_dtypes(include=['float64', 'int'])
to_plot_win.hist(figsize=(12, 12), grid=False)
plt.show()

# %%
means = round(train.mean(),2)
medians = round(train.median(),2)
win_means = round(to_plot_win.mean(),2)
win_medians = round(to_plot_win.median(),2)

# %%
comparison = pd.DataFrame(dict(mean = means,
                               median = medians,
                               mean_change = means - win_means,
                               median_change = medians - win_medians))

# %%
comparison
# Out:
#                      mean  mean_change     median  median_change
# Rooms                3.03         0.01       3.00            0.0
# Price          1051088.01      8418.84  870000.00            0.0
# Distance            11.19         0.04      10.30            0.0
# Postcode          3116.33         0.57    3103.00            0.0
# Bedroom2             3.09         0.02       3.00            0.0
# Bathroom             1.63         0.01       2.00            0.0
# Car                  1.73         0.01       2.00            0.0
# Landsize           595.46        92.19     521.00            0.0
# BuildingArea       161.95         7.70     136.00            0.0
# YearBuilt         1965.65        -0.03    1970.00            0.0
# Lattitude          -37.81         0.00     -37.81            0.0
# Longtitude         145.00         0.00     145.01            0.0
# Propertycount     7560.07        -1.98    6763.00            0.0

# %%
price = train.Price[train.Price.notnull()]
mean = comparison.loc['Price', 'mean']
median = comparison.loc['Price', 'median']

plt.figure(figsize=(12,4))
sns.distplot(price)
plt.axvline(x=mean , color='k', linestyle='-')
plt.axvline(x=median , color='g', linestyle='-')
plt.legend(['mean', 'median'])
plt.show()

# %% [markdown]
# Explain approach
#
# Some skewed could log transform but no need with logistic regression or random forest, maybe after for linear regression

# %% [markdown]
# ### Categorical data

# %%
categorical = train.select_dtypes(include=['object'])
categorical.nunique()
# Out:
# Suburb           345
# Address        27354
# Type               3
# Method             9
# SellerG          365
# CouncilArea       33
# Regionname         8
# Region             8
# dtype: int64

# %% [markdown]
# Anything else??

# %% [markdown]
# #  BUILDING A CLASSIFIER
# __Predicting if a house has more than 3 rooms__

# %% [markdown]
# Look at crosstab results.
#
# Tune Random Forest or log reg for optimizatioin (search on this)
#
# Challenge tune the algorithm without using 'Bedroom2'
#
# Mentioned what's the probability at random of guessing!

# %% [markdown]
# ## Create target variable

# %% [markdown]
# bla bla bla

# %%
# Create specific dataframe for our classifier problem
df_clas = data.copy()

# Transform discrete variable 'Rooms' into a categorical variable
df_clas['>3 Rooms'] = df_clas['Rooms'].apply(lambda x: 1 if x > 3 else 0)

# %% [markdown]
# ## Drop some variables

# %% [markdown]
# drop
# - Address almost no repeated values, won't add value
# - Regionname, we'll use Region (acronyms)
# - Rooms: redundant with '>3 Rooms'

# %%
df_clas.drop(['Address', 'Regionname', 'Rooms'], axis=1, inplace=True)

# %%
train_rooms = df_clas[:train_len]['>3 Rooms']
to_plot_win['>3 Rooms'] = train_rooms

cols = ['Price', 'Distance', 'Landsize', 'YearBuilt']

for col in cols:
    g = sns.FacetGrid(to_plot_win, hue = '>3 Rooms', aspect=4 )
    g.map(sns.kdeplot, col, shade= True )
    x_min = to_plot_win[col].min()
    x_max = to_plot_win[col].max()
    g.add_legend()

# %%
cols = ['Type', 'Method', 'Region']

f, ax = plt.subplots(1,3, figsize=(12,3))
for col, ax in list(zip(cols, ax)):
    ##### TRAIN
    sns.countplot(x=col, hue='>3 Rooms', data=df_clas[:train_len], ax=ax)

# %%
# Create new features for month and day
df_clas['Month'] =  df_clas['Date'].apply(lambda x: x.month)
df_clas['Day'] =  df_clas['Date'].apply(lambda x: x.dayofweek)

# %% [markdown]
# REVIEW THICK GRIDLINES
# #### CORRELATION WITH CATEGORICAL STUFF

# %% [markdown]
# ## Plot correlation matrix

# %%
#correlation heatmap of dataset
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

correlation_heatmap(df_clas[:train_len])

# %% [markdown]
# variables most correlated to 3 rooms are also correlated between them. Random Forest doesn't assume independance, good candidate.
#
# Try log regression, Random Forest, maybe SVC or Gradient Boosting classifiers

# %% [markdown]
# EXPLAIN NO METADATA

# %%
plt.figure(figsize=(5,5))
sns.regplot(train['Bedroom2'], train['Rooms'], x_jitter=0.3, y_jitter=0.3, scatter_kws={"alpha": 0.2})

# %%
# Select variables correlated with target excluding 'Bedrooms'
numeric = ['Price', 'Distance', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Longtitude']
to_plot = to_plot_win[numeric + ['>3 Rooms']]

# %%
pp = sns.pairplot(data=to_plot, vars=numeric, hue='>3 Rooms',palette='dark', size=2,
                  diag_kind='kde', diag_kws=dict(shade=True), plot_kws=dict(s=15),
                 )
pp.set(xticklabels=[])

# %% [markdown]
# ## Preprocess data

# %%
def impute_by_group(train, test):
    na_cols = train.isna().any()
    use_median = na_cols[na_cols == True].index
    medians = train.groupby('Region').median()[use_median]

    train_len = len(train)
    datasets = pd.concat(objs=[train, test], axis=0)

    for row in medians.index:
        for col in medians.columns:
            region = datasets.Region == row
            datasets[col][region] = datasets[col][region].fillna(medians.loc[row,col])

    train, test = datasets[:train_len], datasets[train_len:]
    return train, test

def get_dummies(X_train, X_test):
    train_len = len(X_train)
    datasets = pd.concat(objs=[X_train, X_test], axis=0)
    dummies = pd.get_dummies(datasets)
    X_train, X_test = dummies[:train_len], dummies[train_len:]
    
    return X_train, X_test

def run_model(X_train, X_test, y_train, y_test, model):
    model.fit(X_train, y_train)
    train_score = model.score(X_train, y_train)
    cv_score = cross_val_score(model, X_train, y_train, cv=5).mean()
    start = time.time()
    test_score = model.score(X_test, y_test)    
    end = time.time()
    model_time = end - start
    
    return [train_score, cv_score, test_score, model_time]

# %%
rfc = ensemble.RandomForestClassifier(random_state=13)
lrc = LogisticRegression(penalty='l1', random_state=13)

categoric = list(df_clas.select_dtypes(include=['object']).columns)
features = numeric + categoric
imputing_levels = ['Impute all NaN', 'Impute some NaN', 'Drop all NaN']
feature_selections = ['All features', 'Only numerical', 'Only categorical']

results = []
for level in imputing_levels:
    #split
    train = df_clas[:train_len][features + ['>3 Rooms']] 
    test = df_clas[train_len:][features + ['>3 Rooms']]
    
    # Drop and impute na values as defined
    if level == 'Impute all NaN':
        train, test = impute_by_group(train, test)
        train_all, test_all = train, test # to retrieve later
    elif level == 'Impute some NaN':
        columns = numeric[:]
        columns.remove('BuildingArea')
        train, test = train.dropna(subset=columns), test.dropna(subset=columns)
        train, test = impute_by_group(train, test)
    else:
        train, test = train.dropna(), test.dropna()
    
    for selection in feature_selections:
        if selection == 'All features':
            include = features
        elif selection == 'Only numerical':
            include = numeric
        elif selection == 'Only categorical':
            include = categoric
        
        df_len = len(train) + len(test)
            
        X_train, X_test = train[include], test[include]
        y_train, y_test = train['>3 Rooms'], test['>3 Rooms']
    
        X_train, X_test = get_dummies(X_train, X_test)
        
        for name, model in {'Random Forset': rfc, 'Log. Regression': lrc}.items():
            results.append([name, level, selection, df_len] +
                           run_model(X_train, X_test, y_train, y_test, model)
                          )

# %%
results = pd.DataFrame(results,
                       columns=['Classifier', 'NaN Imputed', 'Features', 'df Length',
                                'Train Score', 'CV-Score', 'Test Score', 'RunTime']
                      )

# %%
(1 - test_all['>3 Rooms'].sum()/len(test_all))
# Out:
# 0.7171760654326302

# %%
results.sort_values(['Test Score'], ascending=False)
# Out:
#          Classifier      NaN Imputed          Features  df Length  \
# 14    Random Forset     Drop all NaN    Only numerical       9235
# 15  Log. Regression     Drop all NaN    Only numerical       9235
# 13  Log. Regression     Drop all NaN      All features       9235
# 7   Log. Regression  Impute some NaN      All features      17679
# 8     Random Forset  Impute some NaN    Only numerical      17679
# 12    Random Forset     Drop all NaN      All features       9235
# 6     Random Forset  Impute some NaN      All features      17679
# 9   Log. Regression  Impute some NaN    Only numerical      17679
# 2     Random Forset   Impute all NaN    Only numerical      34854
# 1   Log. Regression   Impute all NaN      All features      34854
# 0     Random Forset   Impute all NaN      All features      34854
# 3   Log. Regression   Impute all NaN    Only numerical      34854
# 5   Log. Regression   Impute all NaN  Only categorical      34854
# 11  Log. Regression  Impute some NaN  Only categorical      17679
# 4     Random Forset   Impute all NaN  Only categorical      34854
# 17  Log. Regression     Drop all NaN  Only categorical       9235
# 10    Random Forset  Impute some NaN  Only categorical      17679
# 16    Random Forset     Drop all NaN  Only categorical       9235
#
#     Train Score  CV-Score  Test Score   RunTime
# 14     0.988607  0.847146    0.856069  0.007163
# 15     0.827479  0.827207    0.853383  0.001270
# 13     0.856910  0.838737    0.846402  0.013320
# 7      0.852879  0.837954    0.845524  0.039853
# 8      0.988259  0.838945    0.844677  0.012162
# 12     0.989285  0.836022    0.842105  0.028134
# 6      0.988471  0.830669    0.839311  0.064799
# 9      0.821616  0.821191    0.839029  0.001487
# 2      0.975184  0.827398    0.831109  0.034461
# 1      0.836220  0.827578    0.827522  0.067069
# 0      0.987233  0.822664    0.825943  0.152398
# 3      0.810005  0.810221    0.811881  0.002859
# 5      0.759835  0.749507    0.756780  0.059277
# 11     0.758806  0.740768    0.744140  0.022165
# 4      0.836328  0.715689    0.739991  0.101502
# 17     0.754645  0.723720    0.725027  0.013548
# 10     0.839581  0.706959    0.720700  0.049974
# 16     0.861929  0.687232    0.708915  0.024368

# %% [markdown]
# __CHECK RUNTIME STH MORE ACCURATE__

# %%
X_train, y_train = train_all[numeric + categoric], train_all['>3 Rooms']
X_test, y_test = test_all[numeric + categoric], test_all['>3 Rooms']

X_train, X_test = get_dummies(X_train, X_test)

rfc.fit(X_train, y_train)
feat_imp = pd.DataFrame(rfc.feature_importances_, index = X_train.columns,
                        columns=['importance']).sort_values('importance', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='importance', y=feat_imp.index[:25], data= feat_imp[:25])

# %%
# Select numerical features and categorical feature 'type'
X_train = train_all[numeric]
X_test = test_all[numeric]
X_train_mix = train_all[numeric + ['Type', 'Method']]
X_test_mix = test_all[numeric + ['Type', 'Method']]
X_train_mix, X_test_mix = get_dummies(X_train_mix, X_test_mix)

# %%
rfc = ensemble.RandomForestClassifier(random_state=13)
lrc = LogisticRegression(penalty='l1', random_state=13)

# %%
rfc.fit(X_train, y_train)
print(cross_val_score(rfc, X_train, y_train, cv=5).mean())
print(rfc.score(X_test, y_test))
# Out:
# 0.8273982534480779
# 0.8311091978763093

# %%
n_trees = [10, 20, 40, 80, 160, 320, 640, 1280]

trees = []
scores = []

for n_tree in n_trees:
    rfc = ensemble.RandomForestClassifier(random_state=13, n_estimators=n_tree)
    rfc.fit(X_train_mix, y_train)
    trees.append(n_tree)
    scores.append(rfc.score(X_test_mix, y_test))

# %%
plt.plot(trees, scores)

# %%
n_trees = 10
times_from_max = 0

trees = []
scores_train = []
scores_test = []

while times_from_max < 5 and n_trees < 500:
    if not scores_test:
        max_score = 0
    rfc = ensemble.RandomForestClassifier(random_state=13, n_estimators=n_trees)
    rfc.fit(X_train_mix, y_train)
    trees.append(n_trees)
    score_train = cross_val_score(rfc, X_train_mix, y_train, cv=5).mean()
    score_test = rfc.score(X_test_mix, y_test)
    scores_train.append(score_train)
    scores_test.append(score_test)
    if score_test > max_score:
        times_from_max = 0
        max_score = score_test        
    else:
        times_from_max += 1
    n_trees += n_trees
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1003-c77683f29182> in <module>()
#      12     rfc.fit(X_train_mix, y_train)
#      13     trees.append(n_trees)
# ---> 14     score_train = cross_val_score(rfc, X_train_mix, y_train, cv=5).mean()
#      15     score_test = rfc.score(X_test_mix, y_test)
#      16     scores_train.append(score_train)
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     204             fit_params, return_train_score=return_train_score,
#     205             return_times=True)
# --> 206         for train, test in cv.split(X, y, groups))
#     207
#     208     if return_train_score:
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     486         fit_time = time.time() - start_time
#     487         # _score will return dict if is_multimetric is True
# --> 488         test_scores = _score(estimator, X_test, y_test, scorer, is_multimetric)
#     489         score_time = time.time() - start_time - fit_time
#     490         if return_train_score:
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, is_multimetric)
#     521     """
#     522     if is_multimetric:
# --> 523         return _multimetric_score(estimator, X_test, y_test, scorer)
#     524     else:
#     525         if y_test is None:
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _multimetric_score(estimator, X_test, y_test, scorers)
#     551             score = scorer(estimator, X_test)
#     552         else:
# --> 553             score = scorer(estimator, X_test, y_test)
#     554
#     555         if hasattr(score, 'item'):
#
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/scorer.py in _passthrough_scorer(estimator, *args, **kwargs)
#     242 def _passthrough_scorer(estimator, *args, **kwargs):
#     243     """Function that wraps estimator.score"""
# --> 244     return estimator.score(*args, **kwargs)
#     245
#     246
#
# /usr/local/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     347         """
#     348         from .metrics import accuracy_score
# --> 349         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     350
#     351
#
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     536             The predicted classes.
#     537         """
# --> 538         proba = self.predict_proba(X)
#     539
#     540         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     587         Parallel(n_jobs=n_jobs, verbose=self.verbose, backend="threading")(
#     588             delayed(accumulate_prediction)(e.predict_proba, X, all_proba, lock)
# --> 589             for e in self.estimators_)
#     590
#     591         for proba in all_proba:
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in accumulate_prediction(predict, X, out, lock)
#     381
#     382 def accumulate_prediction(predict, X, out, lock):
# --> 383     prediction = predict(X, check_input=False)
#     384     with lock:
#     385         if len(out) == 1:
#
# /usr/local/lib/python3.6/site-packages/sklearn/tree/tree.py in predict_proba(self, X, check_input)
#     820         check_is_fitted(self, 'tree_')
#     821         X = self._validate_X_predict(X, check_input)
# --> 822         proba = self.tree_.predict(X)
#     823
#     824         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
plt.plot(trees[:-1], scores_test)
plt.plot(trees[:-1], scores_train)
plt.legend(['Test', 'Cross-Validation'])

# %% [markdown]
# ADD TOP FEATURES UNTIL OPTIMIZED
# CREATE C OPTIMIZATION THEN CROSSTAB

# %%
# price heat map
price_adjusted = mstats.winsorize(df_some_na['Price'], limits=0.05)
cmap = sns.cubehelix_palette(as_cmap=True, dark=0.1)
x = df_some_na['Longtitude']
y = df_some_na['Lattitude']

f, ax = plt.subplots(figsize=(12,9))
points = ax.scatter(x, y, c=price_adjusted, cmap=cmap, s=15)
f.colorbar(points)
